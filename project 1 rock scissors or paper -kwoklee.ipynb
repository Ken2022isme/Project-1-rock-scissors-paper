# %%
import random

# translating abbreviation to human readable form.
def choice_name(choice):
    if choice=='R':
        return "Rock"
    if choice =='S':
        return "Scissors"
    if choice =='P':
        return "Paper"
    
def play_the_game(player_choice):
# if the computer's choice is placed first and the player choice is placed second in a list
# there are only three possible combinations in which the computer can win
# There is no need to specify the possible choices in which human wins because when the computer doesn't win, 
# human wins. The draw condition is already taken care of.

    computer_winning=[['R','S'],['S','P'],['P','R']]
    
    computer_choice=legal_choice[random.randint(0,2)]
    
    print(f"Computer picks {choice_name(computer_choice)}, you pick {choice_name(player_choice)}")
        
    if computer_choice == player_choice:
        print("It is a draw")
    else:
        combine=[computer_choice, player_choice]
        if combine in computer_winning:
            print("You lose")
        else:
            print("You win")

    print()
# these are the only legal choices
legal_choice=['R','S','P']

# Need a mutable list to iterate over. The length of the list is modifiable and is used to control 
# if the game can continue

k= list(range(2))

print("Welcome to the game of Rock, Scissors and Paper")
print("R for Rock, S for Scissors, P for Paper")

for c in k:

# get the user's choice of rock, scissors, or paper
    player_choice=input("Please choose (R)ock, (S)cissors, or (P)aper: ").upper()

# evaluate to see if the player type in R, S, or P. If not, print a message
    if player_choice not in legal_choice:
        print(player_choice, "is an illegal choice\n")

# player enters a legitimate choice, let the fun begins 
    else:
        play_the_game(player_choice)

# check to see if the player wants to play again

    again=input("Do you want to continue? type 'Y' to continue, any other character means No ").upper()
    if again !='Y':
        k.pop()
    else:
        k.insert(1,1)

print("Thank you for playing the game")
# Out:
# Welcome to the game of Rock, Scissors and Paper
# R for Rock, S for Scissors, P for Paper
# Please choose (R)ock, (S)cissors, or (P)aper: q
# Q is an illegal choice
#
# Do you want to continue? type 'Y' to continue, any other character means No y
# Please choose (R)ock, (S)cissors, or (P)aper: r
# Computer picks Scissors, you pick Rock
# You win
#
# Do you want to continue? type 'Y' to continue, any other character means No y
# Please choose (R)ock, (S)cissors, or (P)aper: w
# W is an illegal choice
#
# Do you want to continue? type 'Y' to continue, any other character means No y
# Please choose (R)ock, (S)cissors, or (P)aper: r
# Computer picks Scissors, you pick Rock
# You win
#
# Do you want to continue? type 'Y' to continue, any other character means No y
# Please choose (R)ock, (S)cissors, or (P)aper: s
# Computer picks Scissors, you pick Scissors
# It is a draw
#
# Do you want to continue? type 'Y' to continue, any other character means No n
# Thank you for playing the game
